# %% [markdown]
# # Using Interval Variables and AddNoOverlap2D constraint for 2D rectangle packing
#
# Given a rectangular container and a set of rectangular items, the goal is to pack all items into the container respecting the orientation of items.
# All rectangles are orthogonal, i.e. they are parallel to the axes of the container.
# Thus, each item is defined by its length and width.
#
# This problem is also known as the 2D bin packing problem and is NP-hard.
# With CP-SAT, we can easily model this problem and solve smaller instances to optimality.

# %%
from ortools.sat.python import cp_model

# %%
# Instance
container = (40, 15)
boxes = [
    (11, 3),
    (13, 3),
    (9, 2),
    (7, 2),
    (9, 3),
    (7, 3),
    (11, 2),
    (13, 2),
    (11, 4),
    (13, 4),
    (3, 5),
    (11, 2),
    (2, 2),
    (11, 3),
    (2, 3),
    (5, 4),
    (6, 4),
    (12, 2),
    (1, 2),
    (3, 5),
    (13, 5),
    (12, 4),
    (1, 4),
    (5, 2),
    # (6,  2),  # add to make tight
    # (6,3), # add to make infeasible
]

# %%
def pack(container, boxes, scale: int):
    container = (container[0] * scale, container[1] * scale)
    boxes = [(box[0] * scale, box[1] * scale) for box in boxes]
    model = cp_model.CpModel()
    # We have to create the variable for the bottom left corner of the boxes.
    # We directly limit their range, such that the boxes are inside the container
    x_vars = [
        model.NewIntVar(0, container[0] - box[0], name=f"x1_{i}")
        for i, box in enumerate(boxes)
    ]
    y_vars = [
        model.NewIntVar(0, container[1] - box[1], name=f"y1_{i}")
        for i, box in enumerate(boxes)
    ]
    # Interval variables are actually more like constraint containers, that are then passed to the no overlap constraint
    # Note that we could also make size and end variables, but we don't need them here
    x_interval_vars = [
        model.NewIntervalVar(
            start=x_vars[i], size=box[0], end=x_vars[i] + box[0], name=f"x_interval_{i}"
        )
        for i, box in enumerate(boxes)
    ]
    y_interval_vars = [
        model.NewIntervalVar(
            start=y_vars[i], size=box[1], end=y_vars[i] + box[1], name=f"y_interval_{i}"
        )
        for i, box in enumerate(boxes)
    ]
    # Enforce that no two rectangles overlap
    model.AddNoOverlap2D(x_interval_vars, y_interval_vars)
    # Solve!
    solver = cp_model.CpSolver()
    solver.parameters.log_search_progress = True
    solver.log_callback = print
    status = solver.Solve(model)
    assert status == cp_model.OPTIMAL

# %%
pack(container, boxes, 1)
# Out:
# Starting CP-SAT solver v9.7.2996
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Parameters: log_search_progress: true
# Setting number of workers to 16
# Setting number of workers to 16
#
#
# Initial satisfaction model '': (model_fingerprint: 0x932179154af0ad79)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Initial satisfaction model '': (model_fingerprint: 0x932179154af0ad79)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
# Starting presolve at 0.00s
#
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=6.01e-07s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=6.01e-07s
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 5.2648e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Symmetry computation done. time: 5.2648e-05 dtime: 5.681e-05
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] Found orbitope of size 2 x 2
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=5.961e-06s
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=5.961e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=8.62e-07s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=8.62e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=7.62e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=7.62e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.21e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=5.41e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=6.91e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.21e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=5.41e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=6.91e-07s
#
#
# Presolve summary:
#   - 0 affine relations were detected.
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#
#
# Presolved satisfaction model '': (model_fingerprint: 0x84a952283b593e1e)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
# Presolved satisfaction model '': (model_fingerprint: 0x84a952283b593e1e)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Preloading model.
#
# Preloading model.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 4.6177e-05 dtime: 5.681e-05
# [Symmetry] Symmetry computation done. time: 4.6177e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# #Model   0.00s var:48/48 constraints:49/49
# #Model   0.00s var:48/48 constraints:49/49
#
#
# Starting search at 0.00s with 16 workers.
# Starting search at 0.00s with 16 workers.
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# #1       0.04s probing fixed_bools:0/108
# #1       0.04s probing fixed_bools:0/108
#
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [ 36.09ms,  36.09ms]  36.09ms   0.00ns  36.09ms         1 [  1.30ms,   1.30ms]   1.30ms   0.00ns   1.30ms
#           'less_encoding':         1 [ 36.08ms,  36.08ms]  36.08ms   0.00ns  36.08ms         1 [  1.32ms,   1.32ms]   1.32ms   0.00ns   1.32ms
#                   'no_lp':         1 [ 36.04ms,  36.04ms]  36.04ms   0.00ns  36.04ms         1 [  1.32ms,   1.32ms]   1.32ms   0.00ns   1.32ms
#                  'max_lp':         1 [ 36.02ms,  36.02ms]  36.02ms   0.00ns  36.02ms         1 [  1.35ms,   1.35ms]   1.35ms   0.00ns   1.35ms
#           'quick_restart':         1 [ 35.97ms,  35.97ms]  35.97ms   0.00ns  35.97ms         1 [  1.15ms,   1.15ms]   1.15ms   0.00ns   1.15ms
#     'quick_restart_no_lp':         1 [ 35.97ms,  35.97ms]  35.97ms   0.00ns  35.97ms         1 [933.87us, 933.87us] 933.87us   0.00ns 933.87us
#                 'probing':         1 [ 35.95ms,  35.95ms]  35.95ms   0.00ns  35.95ms         1 [455.05us, 455.05us] 455.05us   0.00ns 455.05us
#        'feasibility_pump':         1 [ 79.28us,  79.28us]  79.28us   0.00ns  79.28us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':         5 [884.80us,  26.52ms]  11.05ms  12.39ms  55.26ms         1 [971.41us, 971.41us] 971.41us   0.00ns 971.41us
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [ 36.09ms,  36.09ms]  36.09ms   0.00ns  36.09ms         1 [  1.30ms,   1.30ms]   1.30ms   0.00ns   1.30ms
#           'less_encoding':         1 [ 36.08ms,  36.08ms]  36.08ms   0.00ns  36.08ms         1 [  1.32ms,   1.32ms]   1.32ms   0.00ns   1.32ms
#                   'no_lp':         1 [ 36.04ms,  36.04ms]  36.04ms   0.00ns  36.04ms         1 [  1.32ms,   1.32ms]   1.32ms   0.00ns   1.32ms
#                  'max_lp':         1 [ 36.02ms,  36.02ms]  36.02ms   0.00ns  36.02ms         1 [  1.35ms,   1.35ms]   1.35ms   0.00ns   1.35ms
#           'quick_restart':         1 [ 35.97ms,  35.97ms]  35.97ms   0.00ns  35.97ms         1 [  1.15ms,   1.15ms]   1.15ms   0.00ns   1.15ms
#     'quick_restart_no_lp':         1 [ 35.97ms,  35.97ms]  35.97ms   0.00ns  35.97ms         1 [933.87us, 933.87us] 933.87us   0.00ns 933.87us
#                 'probing':         1 [ 35.95ms,  35.95ms]  35.95ms   0.00ns  35.95ms         1 [455.05us, 455.05us] 455.05us   0.00ns 455.05us
#        'feasibility_pump':         1 [ 79.28us,  79.28us]  79.28us   0.00ns  79.28us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':         5 [884.80us,  26.52ms]  11.05ms  12.39ms  55.26ms         1 [971.41us, 971.41us] 971.41us   0.00ns 971.41us
#
# Search stats              Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':    299        300     1'690         6       7'076          5'108
#         'less_encoding':    300        301     1'727         6       7'221          5'156
#                 'no_lp':    300        301     1'716         6       7'183          5'143
#                'max_lp':    224        265     1'015         3       4'872          2'123
#         'quick_restart':    323        287     3'394        28       6'658          3'858
#   'quick_restart_no_lp':    360        260     3'568        26       5'233          3'889
#               'probing':    108        280       580        11       2'476          4'143
#
# Search stats              Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':    299        300     1'690         6       7'076          5'108
#         'less_encoding':    300        301     1'727         6       7'221          5'156
#                 'no_lp':    300        301     1'716         6       7'183          5'143
#                'max_lp':    224        265     1'015         3       4'872          2'123
#         'quick_restart':    323        287     3'394        28       6'658          3'858
#   'quick_restart_no_lp':    360        260     3'568        26       5'233          3'889
#               'probing':    108        280       580        11       2'476          4'143
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':           5/5     60%        0.75       0.10
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':           5/5     60%        0.75       0.10
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      1        0        0        1
#         'lp solutions':     10        5        0        4
#                 'pump':      0        0
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      1        0        0        1
#         'lp solutions':     10        5        0        4
#                 'pump':      0        0
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 419
# conflicts: 334
# branches: 2115
# propagations: 6234
# integer_propagations: 2927
# restarts: 5
# lp_iterations: 0
# walltime: 0.039885
# usertime: 0.0398851
# deterministic_time: 0.0165856
# gap_integral: 0
# solution_fingerprint: 0x397a0422cc046a6
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 419
# conflicts: 334
# branches: 2115
# propagations: 6234
# integer_propagations: 2927
# restarts: 5
# lp_iterations: 0
# walltime: 0.039885
# usertime: 0.0398851
# deterministic_time: 0.0165856
# gap_integral: 0
# solution_fingerprint: 0x397a0422cc046a6

# %%
pack(container, boxes, 10)
# Out:
# Starting CP-SAT solver v9.7.2996
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Parameters: log_search_progress: true
# Setting number of workers to 16
# Setting number of workers to 16
#
#
# Initial satisfaction model '': (model_fingerprint: 0x26124a74348f784d)
# #Variables: 48
#   - 3 in [0,100]
#   - 6 in [0,110]
#   - 6 in [0,120]
#   - 9 in [0,130]
#   - 4 in [0,270]
#   - 2 in [0,280]
#   - 5 in [0,290]
#   - 2 in [0,310]
#   - 2 in [0,330]
#   - 1 in [0,340]
#   - 2 in [0,350]
#   - 2 in [0,370]
#   - 2 in [0,380]
#   - 2 in [0,390]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# Initial satisfaction model '': (model_fingerprint: 0x26124a74348f784d)
# #Variables: 48
#   - 3 in [0,100]
#   - 6 in [0,110]
#   - 6 in [0,120]
#   - 9 in [0,130]
#   - 4 in [0,270]
#   - 2 in [0,280]
#   - 5 in [0,290]
#   - 2 in [0,310]
#   - 2 in [0,330]
#   - 1 in [0,340]
#   - 2 in [0,350]
#   - 2 in [0,370]
#   - 2 in [0,380]
#   - 2 in [0,390]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=6.31e-07s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=6.31e-07s
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 5.4883e-05 dtime: 5.681e-05
# [Symmetry] Symmetry computation done. time: 5.4883e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.693e-06s
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.693e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=9.62e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=1.092e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=9.62e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=1.092e-06s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.1e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.1e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=6.41e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=6.41e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=6.61e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=6.61e-07s
#
#
# Presolve summary:
#   - 0 affine relations were detected.
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#
#
# Presolved satisfaction model '': (model_fingerprint: 0x23daaa54bf3ffcd3)
# #Variables: 48
#   - 3 in [0,100]
#   - 6 in [0,110]
#   - 6 in [0,120]
#   - 9 in [0,130]
#   - 4 in [0,270]
#   - 2 in [0,280]
#   - 5 in [0,290]
#   - 2 in [0,310]
#   - 2 in [0,330]
#   - 1 in [0,340]
#   - 2 in [0,350]
#   - 2 in [0,370]
#   - 2 in [0,380]
#   - 2 in [0,390]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
# Presolved satisfaction model '': (model_fingerprint: 0x23daaa54bf3ffcd3)
# #Variables: 48
#   - 3 in [0,100]
#   - 6 in [0,110]
#   - 6 in [0,120]
#   - 9 in [0,130]
#   - 4 in [0,270]
#   - 2 in [0,280]
#   - 5 in [0,290]
#   - 2 in [0,310]
#   - 2 in [0,330]
#   - 1 in [0,340]
#   - 2 in [0,350]
#   - 2 in [0,370]
#   - 2 in [0,380]
#   - 2 in [0,390]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Preloading model.
#
# Preloading model.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 4.808e-05 dtime: 5.681e-05
# [Symmetry] Symmetry computation done. time: 4.808e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# #Model   0.00s var:48/48 constraints:49/49
# #Model   0.00s var:48/48 constraints:49/49
#
#
# Starting search at 0.00s with 16 workers.
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# Starting search at 0.00s with 16 workers.
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# #1       0.78s probing fixed_bools:0/2410#1       0.78s probing fixed_bools:0/2410
#
#
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [776.73ms, 776.73ms] 776.73ms   0.00ns 776.73ms         1 [197.18ms, 197.18ms] 197.18ms   0.00ns 197.18ms
#           'less_encoding':         1 [776.69ms, 776.69ms] 776.69ms   0.00ns 776.69ms         1 [210.26ms, 210.26ms] 210.26ms   0.00ns 210.26ms
#                   'no_lp':         1 [776.67ms, 776.67ms] 776.67ms   0.00ns 776.67ms         1 [178.62ms, 178.62ms] 178.62ms   0.00ns 178.62ms
#                  'max_lp':         1 [776.61ms, 776.61ms] 776.61ms   0.00ns 776.61ms         1 [153.96ms, 153.96ms] 153.96ms   0.00ns 153.96ms
#           'quick_restart':         1 [776.59ms, 776.59ms] 776.59ms   0.00ns 776.59ms         1 [ 73.09ms,  73.09ms]  73.09ms   0.00ns  73.09ms
#     'quick_restart_no_lp':         1 [776.56ms, 776.56ms] 776.56ms   0.00ns 776.56ms         1 [ 69.51ms,  69.51ms]  69.51ms   0.00ns  69.51ms
#                 'probing':         1 [776.09ms, 776.09ms] 776.09ms   0.00ns 776.09ms         1 [ 42.42ms,  42.42ms]  42.42ms   0.00ns  42.42ms
#        'feasibility_pump':         1 [ 88.31us,  88.31us]  88.31us   0.00ns  88.31us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':         7 [920.36us, 539.28ms] 219.60ms 207.70ms    1.54s         3 [100.01ms, 101.62ms] 100.55ms 755.05us 301.65ms
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [776.73ms, 776.73ms] 776.73ms   0.00ns 776.73ms         1 [197.18ms, 197.18ms] 197.18ms   0.00ns 197.18ms
#           'less_encoding':         1 [776.69ms, 776.69ms] 776.69ms   0.00ns 776.69ms         1 [210.26ms, 210.26ms] 210.26ms   0.00ns 210.26ms
#                   'no_lp':         1 [776.67ms, 776.67ms] 776.67ms   0.00ns 776.67ms         1 [178.62ms, 178.62ms] 178.62ms   0.00ns 178.62ms
#                  'max_lp':         1 [776.61ms, 776.61ms] 776.61ms   0.00ns 776.61ms         1 [153.96ms, 153.96ms] 153.96ms   0.00ns 153.96ms
#           'quick_restart':         1 [776.59ms, 776.59ms] 776.59ms   0.00ns 776.59ms         1 [ 73.09ms,  73.09ms]  73.09ms   0.00ns  73.09ms
#     'quick_restart_no_lp':         1 [776.56ms, 776.56ms] 776.56ms   0.00ns 776.56ms         1 [ 69.51ms,  69.51ms]  69.51ms   0.00ns  69.51ms
#                 'probing':         1 [776.09ms, 776.09ms] 776.09ms   0.00ns 776.09ms         1 [ 42.42ms,  42.42ms]  42.42ms   0.00ns  42.42ms
#        'feasibility_pump':         1 [ 88.31us,  88.31us]  88.31us   0.00ns  88.31us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':         7 [920.36us, 539.28ms] 219.60ms 207.70ms    1.54s         3 [100.01ms, 101.62ms] 100.55ms 755.05us 301.65ms
#
# Search stats              Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':  2'877      2'924    29'159        39   1'238'753        395'016
#         'less_encoding':  2'949      2'996    31'252        39   1'351'976        402'782
#                 'no_lp':  2'792      2'839    26'002        37   1'073'712        384'668
#                'max_lp':  2'572      6'053    32'161        26   1'118'771        146'220
#         'quick_restart':  2'195      2'708    68'976       269     568'811         75'255
#   'quick_restart_no_lp':  1'968      2'753    68'049       274     524'106         75'421
#               'probing':  2'410      3'228    23'483       132     365'071         66'261
#
# Search stats              Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':  2'877      2'924    29'159        39   1'238'753        395'016
#         'less_encoding':  2'949      2'996    31'252        39   1'351'976        402'782
#                 'no_lp':  2'792      2'839    26'002        37   1'073'712        384'668
#                'max_lp':  2'572      6'053    32'161        26   1'118'771        146'220
#         'quick_restart':  2'195      2'708    68'976       269     568'811         75'255
#   'quick_restart_no_lp':  1'968      2'753    68'049       274     524'106         75'421
#               'probing':  2'410      3'228    23'483       132     365'071         66'261
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':           7/7     43%        0.53       0.10
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':           7/7     43%        0.53       0.10
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      1        0        0        1
#         'lp solutions':    163        7      158       12
#                 'pump':      0        0
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      1        0        0        1
#         'lp solutions':    163        7      158       12
#                 'pump':      0        0
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 3597
# conflicts: 3895
# branches: 39888
# propagations: 648911
# integer_propagations: 152292
# restarts: 27
# lp_iterations: 0
# walltime: 0.782327
# usertime: 0.782327
# deterministic_time: 2.13324
# gap_integral: 0
# solution_fingerprint: 0x842c2a3f05478bcf
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 3597
# conflicts: 3895
# branches: 39888
# propagations: 648911
# integer_propagations: 152292
# restarts: 27
# lp_iterations: 0
# walltime: 0.782327
# usertime: 0.782327
# deterministic_time: 2.13324
# gap_integral: 0
# solution_fingerprint: 0x842c2a3f05478bcf

# %%
pack(container, boxes, 100)
# Out:
# Starting CP-SAT solver v9.7.2996
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Parameters: log_search_progress: true
# Setting number of workers to 16
# Setting number of workers to 16
#
#
# Initial satisfaction model '': (model_fingerprint: 0x74eb0f3c80f0c54e)
# #Variables: 48
#   - 3 in [0,1000]
#   - 6 in [0,1100]
#   - 6 in [0,1200]
#   - 9 in [0,1300]
#   - 4 in [0,2700]
#   - 2 in [0,2800]
#   - 5 in [0,2900]
#   - 2 in [0,3100]
#   - 2 in [0,3300]
#   - 1 in [0,3400]
#   - 2 in [0,3500]
#   - 2 in [0,3700]
#   - 2 in [0,3800]
#   - 2 in [0,3900]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Initial satisfaction model '': (model_fingerprint: 0x74eb0f3c80f0c54e)
# #Variables: 48
#   - 3 in [0,1000]
#   - 6 in [0,1100]
#   - 6 in [0,1200]
#   - 9 in [0,1300]
#   - 4 in [0,2700]
#   - 2 in [0,2800]
#   - 5 in [0,2900]
#   - 2 in [0,3100]
#   - 2 in [0,3300]
#   - 1 in [0,3400]
#   - 2 in [0,3500]
#   - 2 in [0,3700]
#   - 2 in [0,3800]
#   - 2 in [0,3900]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=5.81e-07s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=5.81e-07s
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 5.4672e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Symmetry computation done. time: 5.4672e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=5.72e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=6.62e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=6.81e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=2.91e-07s
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=5.72e-06s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=4.61e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=7.02e-07s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=6.62e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=6.81e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=2.91e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=4.61e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=7.02e-07s
#
# Presolve summary:
#   - 0 affine relations were detected.
#
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#
#
# Presolved satisfaction model '': (model_fingerprint: 0x1e6757375b1bc8ad)
# #Variables: 48
#   - 3 in [0,1000]
#   - 6 in [0,1100]
#   - 6 in [0,1200]
#   - 9 in [0,1300]
#   - 4 in [0,2700]
#   - 2 in [0,2800]
#   - 5 in [0,2900]
#   - 2 in [0,3100]
#   - 2 in [0,3300]
#   - 1 in [0,3400]
#   - 2 in [0,3500]
#   - 2 in [0,3700]
#   - 2 in [0,3800]
#   - 2 in [0,3900]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
# Presolved satisfaction model '': (model_fingerprint: 0x1e6757375b1bc8ad)
# #Variables: 48
#   - 3 in [0,1000]
#   - 6 in [0,1100]
#   - 6 in [0,1200]
#   - 9 in [0,1300]
#   - 4 in [0,2700]
#   - 2 in [0,2800]
#   - 5 in [0,2900]
#   - 2 in [0,3100]
#   - 2 in [0,3300]
#   - 1 in [0,3400]
#   - 2 in [0,3500]
#   - 2 in [0,3700]
#   - 2 in [0,3800]
#   - 2 in [0,3900]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Preloading model.
#
# Preloading model.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 4.6497e-05 dtime: 5.681e-05
# [Symmetry] Symmetry computation done. time: 4.6497e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# #Model   0.00s var:48/48 constraints:49/49
# #Model   0.00s var:48/48 constraints:49/49
#
#
# Starting search at 0.00s with 16 workers.
# Starting search at 0.00s with 16 workers.
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# #1       7.58s probing fixed_bools:0/11799
# #1       7.58s probing fixed_bools:0/11799
# #2       7.59s probing fixed_bools:0/11804
# #2       7.59s probing fixed_bools:0/11804
# #3       7.59s probing fixed_bools:0/11804
# #3       7.59s probing fixed_bools:0/11804
# #4       7.59s probing fixed_bools:0/11804
# #4       7.59s probing fixed_bools:0/11804
# #5       7.59s probing fixed_bools:0/11804
# #5       7.59s probing fixed_bools:0/11804
# #6       7.59s probing fixed_bools:0/11804
# #6       7.59s probing fixed_bools:0/11804
# #7       7.60s probing fixed_bools:0/11804
# #7       7.60s probing fixed_bools:0/11804
# #8       7.60s probing fixed_bools:0/11804
# #8       7.60s probing fixed_bools:0/11804
#
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   9.54s,    9.54s]    9.54s   0.00ns    9.54s
#           'less_encoding':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   9.42s,    9.42s]    9.42s   0.00ns    9.42s
#                   'no_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   8.45s,    8.45s]    8.45s   0.00ns    8.45s
#                  'max_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   6.59s,    6.59s]    6.59s   0.00ns    6.59s
#           'quick_restart':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   2.29s,    2.29s]    2.29s   0.00ns    2.29s
#     'quick_restart_no_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   1.34s,    1.34s]    1.34s   0.00ns    1.34s
#                 'probing':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [939.52ms, 939.52ms] 939.52ms   0.00ns 939.52ms
#        'feasibility_pump':         1 [ 78.84us,  78.84us]  78.84us   0.00ns  78.84us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':       111 [552.94us, 563.21ms] 136.23ms 154.28ms   15.12s        55 [ 70.42ms, 100.27ms]  99.55ms   3.96ms    5.47s
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   9.54s,    9.54s]    9.54s   0.00ns    9.54s
#           'less_encoding':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   9.42s,    9.42s]    9.42s   0.00ns    9.42s
#                   'no_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   8.45s,    8.45s]    8.45s   0.00ns    8.45s
#                  'max_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   6.59s,    6.59s]    6.59s   0.00ns    6.59s
#           'quick_restart':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   2.29s,    2.29s]    2.29s   0.00ns    2.29s
#     'quick_restart_no_lp':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [   1.34s,    1.34s]    1.34s   0.00ns    1.34s
#                 'probing':         1 [   7.60s,    7.60s]    7.60s   0.00ns    7.60s         1 [939.52ms, 939.52ms] 939.52ms   0.00ns 939.52ms
#        'feasibility_pump':         1 [ 78.84us,  78.84us]  78.84us   0.00ns  78.84us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':       111 [552.94us, 563.21ms] 136.23ms 154.28ms   15.12s        55 [ 70.42ms, 100.27ms]  99.55ms   3.96ms    5.47s
#
# Search stats               Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':  17'506     17'491   142'844       123  54'743'580     10'458'217
#         'less_encoding':  17'399     17'384   140'363       121  53'844'804     10'434'411
#                 'no_lp':  16'525     16'510   127'440       108  47'614'021      9'057'095
#                'max_lp':  12'486     47'419   211'613        77  54'882'089      6'373'039
#         'quick_restart':   7'123     21'782   656'620     2'160  16'903'466        750'038
#   'quick_restart_no_lp':   6'882     13'404   616'228     1'332  10'196'005        688'442
#               'probing':  11'804     13'882   257'741     1'157   9'212'817        485'662
#
# Search stats               Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':  17'506     17'491   142'844       123  54'743'580     10'458'217
#         'less_encoding':  17'399     17'384   140'363       121  53'844'804     10'434'411
#                 'no_lp':  16'525     16'510   127'440       108  47'614'021      9'057'095
#                'max_lp':  12'486     47'419   211'613        77  54'882'089      6'373'039
#         'quick_restart':   7'123     21'782   656'620     2'160  16'903'466        750'038
#   'quick_restart_no_lp':   6'882     13'404   616'228     1'332  10'196'005        688'442
#               'probing':  11'804     13'882   257'741     1'157   9'212'817        485'662
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':       111/111     50%        0.67       0.10
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':       111/111     50%        0.67       0.10
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      8        0        0        8
#         'lp solutions':  1'092      111      849      119
#                 'pump':      0        0
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      8        0        0        8
#         'lp solutions':  1'092      111      849      119
#                 'pump':      0        0
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 25390
# conflicts: 25637
# branches: 238372
# propagations: 25901919
# integer_propagations: 954442
# restarts: 11
# lp_iterations: 0
# walltime: 7.61623
# usertime: 7.61623
# deterministic_time: 83.845
# gap_integral: 0
# solution_fingerprint: 0xc72ffac878a427
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 25390
# conflicts: 25637
# branches: 238372
# propagations: 25901919
# integer_propagations: 954442
# restarts: 11
# lp_iterations: 0
# walltime: 7.61623
# usertime: 7.61623
# deterministic_time: 83.845
# gap_integral: 0
# solution_fingerprint: 0xc72ffac878a427

# %%
pack(container, boxes, 1000)
# Out:
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
#
# Setting number of workers to 16
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Setting number of workers to 16
#
#
# Initial satisfaction model '': (model_fingerprint: 0x50f40e8ac0ad0a5b)
# #Variables: 48
#   - 3 in [0,10000]
#   - 6 in [0,11000]
#   - 6 in [0,12000]
#   - 9 in [0,13000]
#   - 4 in [0,27000]
#   - 2 in [0,28000]
#   - 5 in [0,29000]
#   - 2 in [0,31000]
#   - 2 in [0,33000]
#   - 1 in [0,34000]
#   - 2 in [0,35000]
#   - 2 in [0,37000]
#   - 2 in [0,38000]
#   - 2 in [0,39000]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# Initial satisfaction model '': (model_fingerprint: 0x50f40e8ac0ad0a5b)
# #Variables: 48
#   - 3 in [0,10000]
#   - 6 in [0,11000]
#   - 6 in [0,12000]
#   - 9 in [0,13000]
#   - 4 in [0,27000]
#   - 2 in [0,28000]
#   - 5 in [0,29000]
#   - 2 in [0,31000]
#   - 2 in [0,33000]
#   - 1 in [0,34000]
#   - 2 in [0,35000]
#   - 2 in [0,37000]
#   - 2 in [0,38000]
#   - 2 in [0,39000]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=5.81e-07s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=5.81e-07s
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 5.3681e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Symmetry computation done. time: 5.3681e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4[Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] Found orbitope of size 2 x 2
#
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] Found orbitope of size 2 x 2
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.181e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=6.61e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=7.92e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=2.5e-07s
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.181e-06s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=9.12e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=6.91e-07s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=6.61e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=7.92e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=2.5e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=9.12e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=6.91e-07s
#
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#
# Presolve summary:
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#
#
# Presolved satisfaction model '': (model_fingerprint: 0x413a5366acad63cb)
# #Variables: 48
#   - 3 in [0,10000]
#   - 6 in [0,11000]
#   - 6 in [0,12000]
#   - 9 in [0,13000]
#   - 4 in [0,27000]
#   - 2 in [0,28000]
#   - 5 in [0,29000]
#   - 2 in [0,31000]
#   - 2 in [0,33000]
#   - 1 in [0,34000]
#   - 2 in [0,35000]
#   - 2 in [0,37000]
#   - 2 in [0,38000]
#   - 2 in [0,39000]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
# Presolved satisfaction model '': (model_fingerprint: 0x413a5366acad63cb)
# #Variables: 48
#   - 3 in [0,10000]
#   - 6 in [0,11000]
#   - 6 in [0,12000]
#   - 9 in [0,13000]
#   - 4 in [0,27000]
#   - 2 in [0,28000]
#   - 5 in [0,29000]
#   - 2 in [0,31000]
#   - 2 in [0,33000]
#   - 1 in [0,34000]
#   - 2 in [0,35000]
#   - 2 in [0,37000]
#   - 2 in [0,38000]
#   - 2 in [0,39000]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Preloading model.
#
# Preloading model.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 4.7069e-05 dtime: 5.681e-05
# [Symmetry] Symmetry computation done. time: 4.7069e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# #Model   0.00s var:48/48 constraints:49/49
# #Model   0.00s var:48/48 constraints:49/49
#
#
# Starting search at 0.00s with 16 workers.
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# Starting search at 0.00s with 16 workers.
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# #1      74.81s probing fixed_bools:0/142075#1      74.81s probing fixed_bools:0/142075
#
# #2      74.83s probing fixed_bools:0/142075
# #2      74.83s probing fixed_bools:0/142075
# #3      74.84s probing fixed_bools:0/142075
# #3      74.84s probing fixed_bools:0/142075
# #4      74.86s probing fixed_bools:0/142075
# #4      74.86s probing fixed_bools:0/142075
# #5      74.87s probing fixed_bools:0/142075
# #5      74.87s probing fixed_bools:0/142075
# #6      74.88s probing fixed_bools:0/142075
# #6      74.88s probing fixed_bools:0/142075
#
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m
#           'less_encoding':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [   1.22m,    1.22m]    1.22m   0.00ns    1.22m
#                   'no_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [   1.15m,    1.15m]    1.15m   0.00ns    1.15m
#                  'max_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  59.84s,   59.84s]   59.84s   0.00ns   59.84s
#           'quick_restart':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  21.15s,   21.15s]   21.15s   0.00ns   21.15s
#     'quick_restart_no_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  17.79s,   17.79s]   17.79s   0.00ns   17.79s
#                 'probing':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  18.47s,   18.47s]   18.47s   0.00ns   18.47s
#        'feasibility_pump':         1 [ 98.01us,  98.01us]  98.01us   0.00ns  98.01us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':       150 [499.88us,   23.54s] 998.10ms    2.99s    2.50m        75 [ 10.07ms, 103.66ms]  98.93ms  10.61ms    7.42s
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m
#           'less_encoding':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [   1.22m,    1.22m]    1.22m   0.00ns    1.22m
#                   'no_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [   1.15m,    1.15m]    1.15m   0.00ns    1.15m
#                  'max_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  59.84s,   59.84s]   59.84s   0.00ns   59.84s
#           'quick_restart':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  21.15s,   21.15s]   21.15s   0.00ns   21.15s
#     'quick_restart_no_lp':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  17.79s,   17.79s]   17.79s   0.00ns   17.79s
#                 'probing':         1 [   1.25m,    1.25m]    1.25m   0.00ns    1.25m         1 [  18.47s,   18.47s]   18.47s   0.00ns   18.47s
#        'feasibility_pump':         1 [ 98.01us,  98.01us]  98.01us   0.00ns  98.01us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':       150 [499.88us,   23.54s] 998.10ms    2.99s    2.50m        75 [ 10.07ms, 103.66ms]  98.93ms  10.61ms    7.42s
#
# Search stats                Bools  Conflicts   Branches  Restarts   BoolPropag  IntegerPropag
#            'default_lp':   58'306     58'287    510'940       117  689'823'690     58'497'358
#         'less_encoding':   57'800     57'781    501'899       110  674'009'032     58'298'061
#                 'no_lp':   56'777     56'758    483'376        91  641'878'934     57'773'719
#                'max_lp':   68'677    171'048    849'509        80  549'127'892      3'315'751
#         'quick_restart':   16'430     84'859  3'338'814     8'388  160'530'017      3'839'229
#   'quick_restart_no_lp':   17'939     74'419  3'235'593     7'365  137'915'668      3'792'081
#               'probing':  142'075    150'126  1'071'772     5'406  185'445'946      2'730'900
#
# Search stats                Bools  Conflicts   Branches  Restarts   BoolPropag  IntegerPropag
#            'default_lp':   58'306     58'287    510'940       117  689'823'690     58'497'358
#         'less_encoding':   57'800     57'781    501'899       110  674'009'032     58'298'061
#                 'no_lp':   56'777     56'758    483'376        91  641'878'934     57'773'719
#                'max_lp':   68'677    171'048    849'509        80  549'127'892      3'315'751
#         'quick_restart':   16'430     84'859  3'338'814     8'388  160'530'017      3'839'229
#   'quick_restart_no_lp':   17'939     74'419  3'235'593     7'365  137'915'668      3'792'081
#               'probing':  142'075    150'126  1'071'772     5'406  185'445'946      2'730'900
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':       150/150     50%        0.72       0.10
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':       150/150     50%        0.72       0.10
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      6        0        0        6
#         'lp solutions':  3'298      150    2'470      775
#                 'pump':      0        0
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      6        0        0        6
#         'lp solutions':  3'298      150    2'470      775
#                 'pump':      0        0
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 129882
# conflicts: 129130
# branches: 1248408
# propagations: 175903581
# integer_propagations: 22139669
# restarts: 5
# lp_iterations: 0
# walltime: 74.936
# usertime: 74.936
# deterministic_time: 583.447
# gap_integral: 0
# solution_fingerprint: 0x22962008a1d6361
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 129882
# conflicts: 129130
# branches: 1248408
# propagations: 175903581
# integer_propagations: 22139669
# restarts: 5
# lp_iterations: 0
# walltime: 74.936
# usertime: 74.936
# deterministic_time: 583.447
# gap_integral: 0
# solution_fingerprint: 0x22962008a1d6361

# %%
pack(container, boxes, 10_000)
# Out:
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Setting number of workers to 16
# Setting number of workers to 16
#
# Initial satisfaction model '': (model_fingerprint: 0x758d3d7aad74b155)
# #Variables: 48
#   - 3 in [0,100000]
#   - 6 in [0,110000]
#   - 6 in [0,120000]
#   - 9 in [0,130000]
#   - 4 in [0,270000]
#   - 2 in [0,280000]
#   - 5 in [0,290000]
#   - 2 in [0,310000]
#   - 2 in [0,330000]
#   - 1 in [0,340000]
#   - 2 in [0,350000]
#   - 2 in [0,370000]
#   - 2 in [0,380000]
#   - 2 in [0,390000]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
#
# Initial satisfaction model '': (model_fingerprint: 0x758d3d7aad74b155)
# #Variables: 48
#   - 3 in [0,100000]
#   - 6 in [0,110000]
#   - 6 in [0,120000]
#   - 9 in [0,130000]
#   - 4 in [0,270000]
#   - 2 in [0,280000]
#   - 5 in [0,290000]
#   - 2 in [0,310000]
#   - 2 in [0,330000]
#   - 1 in [0,340000]
#   - 2 in [0,350000]
#   - 2 in [0,370000]
#   - 2 in [0,380000]
#   - 2 in [0,390000]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=6.01e-07s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=6.01e-07s
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 5.5053e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Symmetry computation done. time: 5.5053e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2[Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
#
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.131e-06s
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.131e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=9.22e-07s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=9.22e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=1.332e-06s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=1.332e-06s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.9e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.9e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=8.52e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=8.52e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=9.82e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=9.82e-07s
#
#
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#
#
# Presolved satisfaction model '': (model_fingerprint: 0xa818096634ddbdfe)
# #Variables: 48
#   - 3 in [0,100000]
#   - 6 in [0,110000]
#   - 6 in [0,120000]
#   - 9 in [0,130000]
#   - 4 in [0,270000]
#   - 2 in [0,280000]
#   - 5 in [0,290000]
#   - 2 in [0,310000]
#   - 2 in [0,330000]
#   - 1 in [0,340000]
#   - 2 in [0,350000]
#   - 2 in [0,370000]
#   - 2 in [0,380000]
#   - 2 in [0,390000]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
# Presolved satisfaction model '': (model_fingerprint: 0xa818096634ddbdfe)
# #Variables: 48
#   - 3 in [0,100000]
#   - 6 in [0,110000]
#   - 6 in [0,120000]
#   - 9 in [0,130000]
#   - 4 in [0,270000]
#   - 2 in [0,280000]
#   - 5 in [0,290000]
#   - 2 in [0,310000]
#   - 2 in [0,330000]
#   - 1 in [0,340000]
#   - 2 in [0,350000]
#   - 2 in [0,370000]
#   - 2 in [0,380000]
#   - 2 in [0,390000]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Preloading model.
#
# Preloading model.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 4.8341e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Symmetry computation done. time: 4.8341e-05 dtime: 5.681e-05
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Found orbitope of size 2 x 2
# #Model   0.00s var:48/48 constraints:49/49
# #Model   0.00s var:48/48 constraints:49/49
#
#
# Starting search at 0.00s with 16 workers.
# Starting search at 0.00s with 16 workers.
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, quick_restart, quick_restart_no_lp]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 7 first solution subsolvers: [random(4), random_quick_restart(3)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
#
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h
#           'less_encoding':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h
#                   'no_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.31h,    1.31h]    1.31h   0.00ns    1.31h
#                  'max_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [  25.73m,   25.73m]   25.73m   0.00ns   25.73m
#           'quick_restart':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [  12.00m,   12.00m]   12.00m   0.00ns   12.00m
#     'quick_restart_no_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [  12.18m,   12.18m]   12.18m   0.00ns   12.18m
#                 'probing':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.00h,    1.00h]    1.00h   0.00ns    1.00h
#        'feasibility_pump':         1 [ 83.78us,  83.78us]  83.78us   0.00ns  83.78us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':       828 [476.83us,    3.70m]   12.38s   22.02s    2.85h       415 [ 29.43ms, 107.97ms] 100.45ms   4.91ms   41.69s
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h
#           'less_encoding':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h
#                   'no_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.31h,    1.31h]    1.31h   0.00ns    1.31h
#                  'max_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [  25.73m,   25.73m]   25.73m   0.00ns   25.73m
#           'quick_restart':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [  12.00m,   12.00m]   12.00m   0.00ns   12.00m
#     'quick_restart_no_lp':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [  12.18m,   12.18m]   12.18m   0.00ns   12.18m
#                 'probing':         1 [   1.42h,    1.42h]    1.42h   0.00ns    1.42h         1 [   1.00h,    1.00h]    1.00h   0.00ns    1.00h
#        'feasibility_pump':         1 [ 83.78us,  83.78us]  83.78us   0.00ns  83.78us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':       828 [476.83us,    3.70m]   12.38s   22.02s    2.85h       415 [ 29.43ms, 107.97ms] 100.45ms   4.91ms   41.69s
#
# Search stats                Bools  Conflicts    Branches  Restarts      BoolPropag  IntegerPropag
#            'default_lp':  468'145    468'110  15'284'735     3'252  50'025'828'118    568'325'709
#         'less_encoding':  467'635    467'600  15'264'857     3'252  49'831'694'451    568'304'811
#                 'no_lp':  457'042    457'007  14'675'138     3'111  45'780'053'986    567'002'553
#                'max_lp':  288'923    289'786     716'408       233  15'864'024'451      4'312'038
#         'quick_restart':   98'641    739'551  66'954'232    72'919   6'132'208'289     73'550'238
#   'quick_restart_no_lp':   95'784    733'209  63'217'849    72'186   6'235'207'883     69'919'198
#               'probing':  257'784    524'458  21'227'830   413'628  36'634'736'939     37'768'316
#
# Search stats                Bools  Conflicts    Branches  Restarts      BoolPropag  IntegerPropag
#            'default_lp':  468'145    468'110  15'284'735     3'252  50'025'828'118    568'325'709
#         'less_encoding':  467'635    467'600  15'264'857     3'252  49'831'694'451    568'304'811
#                 'no_lp':  457'042    457'007  14'675'138     3'111  45'780'053'986    567'002'553
#                'max_lp':  288'923    289'786     716'408       233  15'864'024'451      4'312'038
#         'quick_restart':   98'641    739'551  66'954'232    72'919   6'132'208'289     73'550'238
#   'quick_restart_no_lp':   95'784    733'209  63'217'849    72'186   6'235'207'883     69'919'198
#               'probing':  257'784    524'458  21'227'830   413'628  36'634'736'939     37'768'316
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':       828/828     50%        0.81       0.10
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':       828/828     50%        0.81       0.10
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      0        0        0        0
#         'lp solutions':  7'078      828       86    6'384
#                 'pump':      0        0
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      0        0        0        0
#         'lp solutions':  7'078      828       86    6'384
#                 'pump':      0        0
#
# CpSolverResponse summary:
# status: UNKNOWN
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 312143
# conflicts: 942135
# branches: 1488551
# propagations: 39534927185
# integer_propagations: 11186100736
# restarts: 1
# lp_iterations: 0
# walltime: 5127.24
# usertime: 5127.24
# deterministic_time: 34709.6
# gap_integral: 0
#
# CpSolverResponse summary:
# status: UNKNOWN
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 312143
# conflicts: 942135
# branches: 1488551
# propagations: 39534927185
# integer_propagations: 11186100736
# restarts: 1
# lp_iterations: 0
# walltime: 5127.24
# usertime: 5127.24
# deterministic_time: 34709.6
# gap_integral: 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/krupke/Repositories/cpsat-primer/examples/add_no_overlap_2d_scaling.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/home/krupke/Repositories/cpsat-primer/examples/add_no_overlap_2d_scaling.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> pack(container, boxes, 10_000)
#
# /home/krupke/Repositories/cpsat-primer/examples/add_no_overlap_2d_scaling.ipynb Cell 9 line 2
#      <a href='vscode-notebook-cell:/home/krupke/Repositories/cpsat-primer/examples/add_no_overlap_2d_scaling.ipynb#X15sZmlsZQ%3D%3D?line=17'>18</a> solver.log_callback = print
#      <a href='vscode-notebook-cell:/home/krupke/Repositories/cpsat-primer/examples/add_no_overlap_2d_scaling.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a> status = solver.Solve(model)
# ---> <a href='vscode-notebook-cell:/home/krupke/Repositories/cpsat-primer/examples/add_no_overlap_2d_scaling.ipynb#X15sZmlsZQ%3D%3D?line=19'>20</a> assert status == cp_model.OPTIMAL
#
# AssertionError:
